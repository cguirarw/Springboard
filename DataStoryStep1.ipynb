# %%
import pandas as pd
data = pd.read_csv('C:\\Users\\colew\\2017-18_AdvancedStats_Salary.csv')
print(data)
# Out:
#                       Player        Salary Pos  Age   Tm   G    MP   PER  \
# 0           Shabazz Muhammad   $1,577,230   SF   25  TOR  41   385  14.4
# 1              Isaiah Taylor   $1,312,611   PG   23  ATL  64  1086  11.2
# 2              Rashad Vaughn   $1,889,040   SG   21  TOR  28   212   9.3
# 3                  T.J. Leaf   $2,028,360   PF   20  IND  50   428  10.5
# 4                  Joe Young   $1,471,382   PG   25  IND  50   520  10.2
# 5    Timothe Luwawu-Cabarrot   $1,386,600   SF   22  PHI  52   807   7.0
# 6              Jahlil Okafor   $4,995,120    C   22  TOR  28   353  15.4
# 7              Jahlil Okafor   $4,995,120    C   22  BRK  26   328  15.9
# 8                  Ian Clark   $1,577,230   SG   26  NOP  72  1398   9.1
# 9               Wayne Selden   $1,312,611   SG   23  MEM  35   692  11.8
# 10              Nik Stauskas   $3,807,146   SG   24  TOR  37   459   9.1
# 11            Jamal Crawford  $10,942,762   SG   37  MIN  76  1566  13.5
# ...

# %%
import matplotlib.pyplot as plt
x = data['Salary']
y = data['VORP']
plt.scatter(x, y)
plt.show()

# %%
plt.show()

# %%
plt.scatter(x,y)

# %%
plt.show()

# %%
x = data['VORP']
y = data['Salary']
plt.scatter(x, y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-cf0ec8fc25f2> in <module>()
# ----> 1 x = data['VORP']
#       2 y = data['Salary']
#       3 plt.scatter(x, y)
#
# NameError: name 'data' is not defined

# %%
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv('C:\\Users\\colew\\2017-18_AdvancedStats_Salary.csv')
x = data['VORP']
y = data['Salary']
plt.scatter(x, y)
plt.show()

# %%
#As VORP increases Salary increases logarithmically.

# %%
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv('C:\\Users\\colew\\2017-18_AdvancedStats_Salary.csv')
x = data['Age']
y = data['Salary']
plt.scatter(x, y)
plt.show()

# %%
#There seems to be no relationship between age and salary.

# %%
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv('C:\\Users\\colew\\2017-18_AdvancedStats_Salary.csv')
x = data['Pos']
y = data['Salary']
plt.scatter(x, y)
plt.show()

# %%
#There seems to be a slight increase in salary for point guards, shooting guards, and power forwards.

# %%
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv('C:\\Users\\colew\\2017-18_AdvancedStats_Salary.csv')
x = data['PER']
y = data['Salary']
plt.scatter(x, y)
plt.show()

# %%
#There seems to be a loose trend upward logarithmically indicating a higher PER gives you a better chance at a higher salary.

# %%
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv('C:\\Users\\colew\\2017-18_AdvancedStats_Salary.csv')
x = data['TS%']
y = data['Salary']
plt.scatter(x, y)
plt.show()

import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv('C:\\Users\\colew\\2017-18_AdvancedStats_Salary.csv')
x = data['TRB%']
y = data['Salary']
plt.scatter(x, y)
plt.show()

# %%
#There doesn't seem to be any relationship between salary and total rebound percentage or salary and true shooting percentage.

# %%
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv('C:\\Users\\colew\\2017-18_AdvancedStats_Salary.csv')
x = data['AST%']
y = data['Salary']
plt.scatter(x, y)
plt.show()

import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv('C:\\Users\\colew\\2017-18_AdvancedStats_Salary.csv')
x = data['STL%']
y = data['Salary']
plt.scatter(x, y)
plt.show()

import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv('C:\\Users\\colew\\2017-18_AdvancedStats_Salary.csv')
x = data['BLK%']
y = data['Salary']
plt.scatter(x, y)
plt.show()

import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv('C:\\Users\\colew\\2017-18_AdvancedStats_Salary.csv')
x = data['TOV%']
y = data['Salary']
plt.scatter(x, y)
plt.show()

import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv('C:\\Users\\colew\\2017-18_AdvancedStats_Salary.csv')
x = data['USG%']
y = data['Salary']
plt.scatter(x, y)
plt.show()

import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv('C:\\Users\\colew\\2017-18_AdvancedStats_Salary.csv')
x = data['OWS']
y = data['Salary']
plt.scatter(x, y)
plt.show()

import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv('C:\\Users\\colew\\2017-18_AdvancedStats_Salary.csv')
x = data['DWS']
y = data['Salary']
plt.scatter(x, y)
plt.show()

import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv('C:\\Users\\colew\\2017-18_AdvancedStats_Salary.csv')
x = data['WS']
y = data['Salary']
plt.scatter(x, y)
plt.show()

import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv('C:\\Users\\colew\\2017-18_AdvancedStats_Salary.csv')
x = data['BPM']
y = data['Salary']
plt.scatter(x, y)
plt.show()

# %%
#There seems to be a very loose logarithmic trend upward indicating an increase in assist percentage gives a better chance at a higher salary.
#There seems to be no relationship between steal percentage and salary.
#There seems to be no relationshup between block percentage and salary.
#There seems to be no relationship between turnover percentage and salary.
#There seems to be a very loose  trend upward indicating an increase in usage percentage gives a better chance at a higher salary.
#There seems to be a very steep logarithmic trend upward indicating an increase in offensive win shares gives a much better chance at a higher salary.
#There seems to be a logarithmic trend upward indicating an increase in defensive win shares gives a better chance at a higher salary.
#There seems to be a logarithmic trend upward indicating an increase in win shares gives a better chance at a higher salary.
#There seems to be a logarithmic trend upward indicating an increase in box plus/minus score gives a better chance at a higher salary.

# %%
#I find it very interesting that there's basically no relationship between salary and almost any of the percentage statistics.
#I find it it very interesting that the relationship between win shares and salary isn't closer to a straight line.
#I was able to find multiple trends.
#I could make a bar plot or histogram, but it wouldn't help for what I'm trying to figure out.
#I made multiple scatter plots.
#I cannot make a time-series plot.
#I would like to look further into the relationship between win shares and salary, box plus/minus score and salary, assist percentage and salary, VORP and salary, and PER and salary.
#My current hypothesis, is that teams are overvaluing the likely overall value of a player in a vacuum and not valuing the individual advanced statistics of players enough.
#By looking at total money spent per team, individual statistics, and win/loss records I could probably present a story that most likely best shows proof of my hypothesis.

# %%
#Here is a link to the dataset: https://www.kaggle.com/meicher/201718-advanced-player-metrics-salary#2017-18_AdvancedStats_Salary.csv
